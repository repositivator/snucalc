# %%
StudyAnalysis
# Out:
# calcmain.models.StudyAnalysis

# %%
from django.shortcuts import render, redirect, get_object_or_404
study = get_object_or_404(StudyAnalysis, pk=4)

# %%
study = StudyAnalysis.objects.filter(study_name="Test")

# %%
dir(study)
# Out:
# ['__and__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_hints',
#  '_as_sql',
#  '_batched_insert',
#  '_clone',
#  '_create_object_from_params',
#  '_db',
#  '_earliest_or_latest',
#  '_extract_model_params',
#  '_fetch_all',
#  '_fields',
#  '_filter_or_exclude',
#  '_for_write',
#  '_has_filters',
#  '_hints',
#  '_insert',
#  '_iterable_class',
#  '_known_related_objects',
#  '_merge_known_related_objects',
#  '_merge_sanity_check',
#  '_next_is_sticky',
#  '_populate_pk_values',
#  '_prefetch_done',
#  '_prefetch_related_lookups',
#  '_prefetch_related_objects',
#  '_prepare',
#  '_raw_delete',
#  '_result_cache',
#  '_sticky_filter',
#  '_update',
#  '_values',
#  'aggregate',
#  'all',
#  'annotate',
#  'as_manager',
#  'bulk_create',
#  'complex_filter',
#  'count',
#  'create',
#  'dates',
#  'datetimes',
#  'db',
#  'defer',
#  'delete',
#  'distinct',
#  'earliest',
#  'exclude',
#  'exists',
#  'extra',
#  'filter',
#  'first',
#  'get',
#  'get_or_create',
#  'in_bulk',
#  'is_compatible_query_object_type',
#  'iterator',
#  'last',
#  'latest',
#  'model',
#  'none',
#  'only',
#  'order_by',
#  'ordered',
#  'prefetch_related',
#  'query',
#  'raw',
#  'reverse',
#  'select_for_update',
#  'select_related',
#  'update',
#  'update_or_create',
#  'using',
#  'value_annotation',
#  'values',
#  'values_list']

# %%
study_id = study.pk
study_name = study.study_name
imported_sheet = study.imported_sheet
up_patients = study.up_patients

print(study_id, study_name, imported_sheet, up_patients)
# Out:
# 4 test3 files/imported_sheets/sample_LYUBvAW.xlsx 10

# %%
import pandas as pd

# %%
main_df = pd.read_excel(study.imported_sheet, sheetname=0)

# %%
main_df
# Out:
#      ID             Organ  Lesion size at baseline (mm)  \
# 0     1              Lung                            55
# 1     1              Lung                            71
# 2     1        Lymph node                            14
# 3     2              Lung                            35
# 4     2        Lymph node                            80
# 5     2        Lymph node                            29
# 6     3              Lung                            44
# 7     3        Lymph node                            76
# 8     3        Lymph node                            28
# 9     4       Mediastinum                            79
# 10    4        Lymph node                            61
# 11    4        Lymph node                            24
# 12    4           Adrenal                           113
# 13    4           Adrenal                            55
# 14    5  Lung/mediastinum                            99
# 15    5              Lung                            40
# 16    5        Lymph node                            22
# 17    6              Lung                           117
# 18    6        Lymph node                            10
# 19    6        Lymph node                            50
# 20    6             Liver                           137
# 21    6             Liver                            74
# 22    7              Lung                            87
# 23    7        Lymph node                            66
# 24    7           Adrenal                            80
# 25    8        Lymph node                            76
# 26    8        Lymph node                            62
# 27    9              Lung                            29
# 28    9             Liver                            33
# 29   10              Lung                           110
# ..   ..               ...                           ...
# 71   22        Lymph node                            24
# 72   22        Lymph node                            21
# 73   23              Lung                           143
# 74   23        Lymph node                            47
# 75   23        Lymph node                            46
# 76   23           Adrenal                           139
# 77   24  Lung/mediastinum                            62
# 78   24        Lymph node                            45
# 79   24        Lymph node                            55
# 80   24             Liver                            94
# 81   25              Lung                           126
# 82   25              Lung                            14
# 83   25        Lymph node                            78
# 84   25           Adrenal                            55
# 85   25             Liver                            34
# 86   26              Lung                            51
# 87   26        Lymph node                            13
# 88   26        Lymph node                            26
# 89   27              Lung                           107
# 90   27              Lung                            27
# 91   27        Lymph node                            12
# 92   27        Lymph node                            78
# 93   28        Lymph node                            54
# 94   28        Lymph node                            70
# 95   28           Adrenal                            76
# 96   28           Adrenal                           111
# 97   29        Lymph node                            45
# 98   30              Lung                           111
# 99   30        Lymph node                            22
# 100  30        Lymph node                            66
#
#      Lesion size at post-treatment (mm)
# 0                                   138
# 1                                   102
# 2                                    15
# 3                                    44
# 4                                    42
# 5                                    68
# 6                                    36
# 7                                     0
# 8                                    56
# 9                                   121
# 10                                   26
# 11                                   59
# 12                                  125
# 13                                  138
# 14                                   34
# 15                                  103
# 16                                   84
# 17                                   88
# 18                                    7
# 19                                    7
# 20                                   18
# 21                                   10
# 22                                   40
# 23                                   39
# 24                                   86
# 25                                   63
# 26                                   26
# 27                                   94
# 28                                  112
# 29                                  105
# ..                                  ...
# 71                                   11
# 72                                   30
# 73                                    7
# 74                                    5
# 75                                   28
# 76                                  102
# 77                                    5
# 78                                   86
# 79                                   21
# 80                                   30
# 81                                   72
# 82                                  104
# 83                                   84
# 84                                  101
# 85                                  119
# 86                                   54
# 87                                   15
# 88                                   57
# 89                                  107
# 90                                  161
# 91                                   38
# 92                                    9
# 93                                   85
# 94                                   28
# 95                                   27
# 96                                  119
# 97                                   83
# 98                                   42
# 99                                   22
# 100                                  20
#
# [101 rows x 4 columns]

# %%
len(main_df.ID.unique())
# Out:
# 30
